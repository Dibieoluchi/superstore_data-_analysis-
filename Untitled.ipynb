# %% [markdown]
# # SUPER STORE DATA ANALYSIS
#
#
# Thias Dataset belongs to a Superstore Giant in the USA ,it contains a total of 9994 data.
#
# # AIM :The purpose of this analysis is to ascertain whether Sales have improved across the factors that have been indicated as potential influencing factors for this superstore
#
#
# # Potential factors
#
# 1. Order Date => Order Date of the product.
# 2. Segment => The segment where the Customer belongs.
# 3. City => City of residence of of the Customer.
# 4. State => State of residence of the Customer.
# 5. Category => Category of the product ordered.

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Superstore editted.csv', encoding='windows-1252', parse_dates=['Order Date', 'Ship Date']) #saved to right file format for my device

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date    Ship Mode    Customer ID  \
# 0    3783  CA-2017-165204 2017-11-13 2017-11-16     Consumer  United States
# 1    1990  CA-2015-127509 2015-11-09 2015-11-13     Consumer  United States
# 2    2949  CA-2017-169859 2017-12-14 2017-12-18  Home Office  United States
# 3    4993  CA-2015-153038 2015-12-18 2015-12-25    Corporate  United States
# 4    5689  CA-2014-131541 2014-07-28 2014-07-28     Consumer  United States
#
#   Customer Name     Segment Country     City  ...      Postal Code     Region  \
# 0       Memphis   Tennessee   38109    South  ...  Office Supplies      Paper
# 1   Springfield    Missouri   65807  Central  ...  Office Supplies  Envelopes
# 2     San Diego  California   92024     West  ...  Office Supplies  Envelopes
# 3       Memphis   Tennessee   38109    South  ...  Office Supplies  Envelopes
# 4        Apopka     Florida   32712    South  ...  Office Supplies  Envelopes
#
#                                           Product ID Category Sub-Category  \
# 0  "While you Were Out" Message Book, One Form pe...    8.904            3
# 1            #10- 4 1/8" x 9 1/2" Recycled Envelopes    26.22            3
# 2            #10- 4 1/8" x 9 1/2" Recycled Envelopes     43.7            5
# 3            #10- 4 1/8" x 9 1/2" Recycled Envelopes   55.936            8
# 4            #10- 4 1/8" x 9 1/2" Recycled Envelopes   48.944            7
#
#   Product Name    Sales  Quantity  Discount   Profit
# 0          0.2   3.3390         3       0.2   3.3390
# 1            0  12.3234         3       0.0  12.3234
# 2            0  20.5390         5       0.0  20.5390
# 3          0.2  18.8784         8       0.2  18.8784
# 4          0.2  16.5186         7       0.2  16.5186
#
# [5 rows x 21 columns]

# %%
data.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date    Ship Mode  \
# 9989    2121  US-2017-168690 2017-01-07 2017-01-13     Consumer
# 9990    7312  CA-2015-162761 2015-10-09 2015-10-13     Consumer
# 9991    5274  US-2016-158309 2016-11-26 2016-11-29  Home Office
# 9992    3408  US-2014-150119 2014-04-23 2014-04-27  Home Office
# 9993    7896  CA-2017-124744 2017-06-21 2017-06-25  Home Office
#
#         Customer ID Customer Name        Segment Country   City  ...  \
# 9989  United States  Ormond Beach        Florida   32174  South  ...
# 9990  United States         Miami        Florida   33178  South  ...
# 9991  United States         Miami        Florida   33142  South  ...
# 9992  United States      Columbus           Ohio   43229   East  ...
# 9993  United States      Wheeling  West Virginia   26003   East  ...
#
#           Postal Code   Region                  Product ID Category  \
# 9989  Office Supplies  Binders  Zipper Ring Binder Pockets    2.808
# 9990  Office Supplies  Binders  Zipper Ring Binder Pockets    1.872
# 9991  Office Supplies  Binders  Zipper Ring Binder Pockets    3.744
# 9992  Office Supplies  Binders  Zipper Ring Binder Pockets    7.488
# 9993  Office Supplies  Binders  Zipper Ring Binder Pockets     6.24
#
#      Sub-Category Product Name   Sales  Quantity  Discount  Profit
# 9989            3          0.7 -1.9656         3       0.7 -1.9656
# 9990            2          0.7 -1.3104         2       0.7 -1.3104
# 9991            4          0.7 -2.6208         4       0.7 -2.6208
# 9992            8          0.7 -5.2416         8       0.7 -5.2416
# 9993            2            0  3.0576         2       0.0  3.0576
#
# [5 rows x 21 columns]

# %%
data.shape      # they are 9994 rows and 21 columns
# Out:
# (9994, 21)

# %%
data.describe()
# Out:
#             Row ID         Sales     Quantity     Discount       Profit
# count  9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   4997.500000    105.466244     3.789574     0.156203    28.656896
# std    2885.163629    410.990504     2.225110     0.206452   234.260108
# min       1.000000  -3701.892800     1.000000     0.000000 -6599.978000
# 25%    2499.250000      4.852575     2.000000     0.000000     1.728750
# 50%    4997.500000     17.522000     3.000000     0.200000     8.666500
# 75%    7495.750000     72.168000     5.000000     0.200000    29.364000
# max    9994.000000  17499.950000    14.000000     0.800000  8399.976000

# %%
data.info() # no missing value in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   object
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(14)
# memory usage: 1.6+ MB

# %% [markdown]
# **observation**
# i already corrected my order date  to the right format on excel

# %% [markdown]
# # VISUALIZATION

# %% [markdown]
# 1. Order Date => Order Date of the product.
# 2. Segment => The segment where the Customer belongs.
# 3. City => City of residence of of the Customer.
# 4. State => State of residence of the Customer.
# 5. Category => Category of the product ordered.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   object
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(14)
# memory usage: 1.6+ MB

# %%
sns.histplot(x='Sales', data=data, color='purple')
plt.title(' kde Distribution of patients age')
plt.xlabel('Age')
plt.show()
